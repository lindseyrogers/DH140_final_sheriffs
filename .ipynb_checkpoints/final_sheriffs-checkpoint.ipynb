# %%
# importing packages

import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
import numpy as np
import folium
import datetime

# %% [markdown]
# # Introduction
# ---

# %% [markdown]
# Constitutional Sheriffs are a self-described group of elected county sheriffs that subscribe to the belief that the local sheriff is the highest authority in the United States. They believe their power is higher than both the federal and state government, leaving them the power to decide which laws are unconstitutional and are not to be enforced. Most notably, these sheriffs have refused to enforce COVID and gun control regulations.
#
# Studying Constitutional Sheriffs is difficult because there is not a complete and definite list of Constitutional Sheriffs as members are self-described. To study these sheriffs, I am working on developing a working list of Constitutional Sheriffs and addressing sheriff trends with proxy data. For this class, I will be using Python coding skills to address the following research questions:
# ### <div align = "center"> How has sheriff and police violence changed over time?
# ### <div align = "center"> Where is sheriff violence happening? Are there spatial trends that emerge from the data?
#
#
# This project uses two primary datasets for analysis. The first dataset is the [Mapping Police Violence database](https://mappingpoliceviolence.org/). This is a collection of data on civilians killed by police or sheriff officers since 2013. The dataset has over 10,000 entries with information such as the name of the victim, the agency responsible, and the lat and long location of the death. This dataset was downloaded from the link, then I simplified the dataset in excel and uploaded the simplified dataset to my personal github. The second dataset is the [UCLA Law COVID 19 Behind Bars dataset](https://uclacovidbehindbars.org/intro-carceral-mortality). This dataset is primarly focued on collecting information relating to deaths within US federal prisons. Relating to sheriff violence, there are a few points of data relating to deaths within county prisons. This data, collected by facility, will be extracted for analysis. This dataset is accessed through the UCLA Law Behind Bars github.

# %% [markdown]
# ## Mapping Police Violence Dataset
#
# Here, I am saving a simplified csv file of the Mapping Police Violence Dataset to a variable called 'mpv'. Each row shows data of a fatal police encounter in the United States.

# %%
mpv = pd.read_csv('https://raw.githubusercontent.com/lindseyrogers/DH140_final_sheriffs/main/MPV_Simplified2.csv')
mpv.head()
# Out:
#                 name   age  gender   race        date  \
# 0    Warren Merriman   NaN    Male    NaN  12/28/2022
# 1    Terry L. Bowman  39.0    Male  White  12/28/2022
# 2     Monet Darrisaw  34.0  Female  Black  12/27/2022
# 3  Trevontay Jenkins  16.0    Male    NaN  12/26/2022
# 4   Zachary D. Zoran  34.0    Male  White  12/26/2022
#
#                                       street_address            city state  \
# 0                       100 block of East 4th Street  San Bernardino    CA
# 1                     15000 block of U.S. 40 Highway    Independence    MO
# 2  intersection of West Boulevard and Donald Ross...       Charlotte    NC
# 3                                400 E. McKinley Ave      Des Moines    IA
# 4                     500 block of W. Hopocan Avenue       Barberton    OH
#
#        zip          county  ... wapo_armed            wapo_threat_level  \
# 0  92410.0  San Bernardino  ...      Knife  Sudden Threatening Movement
# ...

# %% [markdown]
# ## Census Data
#
# The 2021 and 2022 population counts by state in a variable called 'census'.

# %%
#importing the census data
census = pd.read_csv('/home/jovyan/DH140_final_sheriffs/census_pop2.csv')
census.head()
# Out:
#   state      2021      2022
# 0    AL   5049846   5074296
# 1    AK    734182    733583
# 2    AZ   7264877   7359197
# 3    AR   3028122   3045637
# 4    CA  39142991  39029342

# %% [markdown]
# ## UCLA Law Behind Bars Data
#
# The variable 'lfc' is a pandas dataframe of the latest facility counts, read from the UCLA Behind Bar's github. Each row shows data relating to a single prison facility in the United States.

# %%
lfc = pd.read_csv('https://media.githubusercontent.com/media/uclalawcovid19behindbars/data/master/latest-data/latest_facility_counts.csv')
lfc.head()
# Out:
#    Facility.ID Jurisdiction    State  \
# 0            1        state  Alabama
# 1            2        state  Alabama
# 2            3        state  Alabama
# 3            5        state  Alabama
# 4            6        state  Alabama
#
#                                        Name        Date  \
# 0                      ALABAMA HEADQUARTERS  2023-01-18
# 1  ALABAMA TREATMENT AND EDUCATION FACILITY  2023-01-18
# 2        ALEX CITY COMMUNITY BASED FACILITY  2023-01-18
# 3                BIBB CORRECTIONAL FACILITY  2023-01-18
# 4       BIRMINGHAM COMMUNITY BASED FACILITY  2023-01-18
#
#                                    source  Residents.Confirmed  \
# 0  http://www.doc.alabama.gov/covid19news                  0.0
# 1  http://www.doc.alabama.gov/covid19news                 47.0
# 2  http://www.doc.alabama.gov/covid19news                 85.0
# 3  http://www.doc.alabama.gov/covid19news                197.0
# 4  http://www.doc.alabama.gov/covid19news                106.0
#
# ...

# %% [markdown]
# # Methods
# ---
#
# The methods section of this projects takes the three datasets defined above and extracts, merges, and calculates statistics that can be later used to show relationships in graphs and maps.

# %% [markdown]
# #### MPV with Year
#
# I converted the mm/dd/yyyy date format from the original dataset into a single year column using a date-time package. This process did not create a new variable, but modified the original dataset.

# %%
# This code is taking the date column, converting it to a datetime, then creating a new column with only the year
mpv['date2'] = pd.DataFrame({'InsertedDate':pd.to_datetime(mpv['date'])})
mpv['year'] = mpv['date2'].dt.strftime('%Y')
mpv.head()
# Out:
#                 name   age  gender   race        date  \
# 0    Warren Merriman   NaN    Male    NaN  12/28/2022
# 1    Terry L. Bowman  39.0    Male  White  12/28/2022
# 2     Monet Darrisaw  34.0  Female  Black  12/27/2022
# 3  Trevontay Jenkins  16.0    Male    NaN  12/26/2022
# 4   Zachary D. Zoran  34.0    Male  White  12/26/2022
#
#                                       street_address            city state  \
# 0                       100 block of East 4th Street  San Bernardino    CA
# 1                     15000 block of U.S. 40 Highway    Independence    MO
# 2  intersection of West Boulevard and Donald Ross...       Charlotte    NC
# 3                                400 E. McKinley Ave      Des Moines    IA
# 4                     500 block of W. Hopocan Avenue       Barberton    OH
#
#        zip          county  ...    wapo_flee wapo_body_camera  \
# 0  92410.0  San Bernardino  ...  Not Fleeing              Yes
# ...

# %% [markdown]
# #### MPV in 2022
#
# I slimed down the mapping police violence dataset to a variable called mpv_2022 to only contain fatal police encounters for the year 2022, the most recent full year of data collected on the database.

# %%
mpv_2022 = mpv.loc[ mpv['year'] == '2022' ]
mpv_2022.head()
# Out:
#                 name   age  gender   race        date  \
# 0    Warren Merriman   NaN    Male    NaN  12/28/2022
# 1    Terry L. Bowman  39.0    Male  White  12/28/2022
# 2     Monet Darrisaw  34.0  Female  Black  12/27/2022
# 3  Trevontay Jenkins  16.0    Male    NaN  12/26/2022
# 4   Zachary D. Zoran  34.0    Male  White  12/26/2022
#
#                                       street_address            city state  \
# 0                       100 block of East 4th Street  San Bernardino    CA
# 1                     15000 block of U.S. 40 Highway    Independence    MO
# 2  intersection of West Boulevard and Donald Ross...       Charlotte    NC
# 3                                400 E. McKinley Ave      Des Moines    IA
# 4                     500 block of W. Hopocan Avenue       Barberton    OH
#
#        zip          county  ...    wapo_flee wapo_body_camera  \
# 0  92410.0  San Bernardino  ...  Not Fleeing              Yes
# ...

# %% [markdown]
# #### MPV by State (2022)
#
# Here, I created a new variable called mpv_state_2022 that counted the number of fatal police encounters for each state for the year 2022. This data will be used later to create maps.

# %%
mpv_state_2022 = pd.DataFrame()
mpv_state_2022['state'] = mpv_2022['state'].unique()
mpv_state_2022['state_count'] = list(mpv_2022['state'].value_counts())
mpv_state_2022.head()
# Out:
#   state  state_count
# 0    CA          142
# 1    MO          124
# 2    NC           77
# 3    IA           62
# 4    OH           58

# %% [markdown]
# #### MPV by Year
#
# Preliminary data exploration indicated there may be a trend of police violence overtime. Here, the variable year_mpv counts the number of fatal police encounter by year.

# %%
year_mpv = pd.DataFrame()
year_mpv['year'] = mpv['year'].unique()
year_mpv['total_count'] = list(mpv['year'].value_counts())
year_mpv.head()
# Out:
#    year  total_count
# 0  2022         1211
# 1  2021         1160
# 2  2020         1146
# 3  2019         1144
# 4  2018         1105

# %% [markdown]
# #### MPV by State (All-time)
#
# Similar to the mapping police violence for 2022, the variable state_mpv provides a count of fatal police encounters in each state. This data contains data from 2013 to present.

# %%
state_mpv = pd.DataFrame()
state_mpv['state'] = mpv['state'].unique()
state_mpv['state_count'] = list(mpv['state'].value_counts())
state_mpv.head()
# Out:
#   state  state_count
# 0    CA         1651
# 1    MO         1037
# 2    NC          769
# 3    IA          492
# 4    OH          430

# %% [markdown]
# #### MPV and Census
#
# Using the state as a merge feature, the variable 'mpv_sorted' combines data from 2022 in the mapping police violence dataset with 2022 population counts. The number of fatal encounters was divided by the population of the state and multiplied by 1,000,000. This value was then sorted from low to high to display a per capita value of fatal police encounters in each state.

# %%
mpv_merged = pd.merge(census, mpv_state_2022, on='state')
mpv_merged['percap'] = mpv_merged['state_count']/mpv_merged['2022']*1000000
mpv_merged.head()
# Out:
#   state      2021      2022  state_count     percap
# 0    AL   5049846   5074296           28   5.518007
# 1    AK    734182    733583           38  51.800546
# 2    AZ   7264877   7359197           13   1.766497
# 3    AR   3028122   3045637           21   6.895109
# 4    CA  39142991  39029342          142   3.638288

# %%
mpv_sorted = mpv_merged.sort_values(by='percap')
mpv_sorted.head()
# Out:
#    state      2021      2022  state_count    percap
# 21    MA   6989690   6981974            1  0.143226
# 30    NJ   9267961   9261699            4  0.431886
# 38    PA  13012059  12972008            7  0.539623
# 9     FL  21828069  22244823           19  0.854131
# 39    RI   1096985   1093734            1  0.914299

# %% [markdown]
# ### Review of Data Processing
#
# |DataFrame Name|Description|
# |:---:|:---|
# |mpv|Mapping Police Violence Data with Year column
# |lcf| UCLA Behind Bars Data (stands for Latest Facility Count)
# |mpv_2022| Mapping Police Violence Data from 2022
# |mpv_state_2022 |Sums of police violence in 2022 by state
# |year_mpv| Sums of police violence by year
# |mpv_merged| Calculated police violence per capita in 2022
# |mpv_sorted| Sorted mpv_merged by percapita

# %% [markdown]
# # Results
# ---

# %% [markdown]
# ## Mapping Police Violence

# %%
year_mpvsorted = year_mpv.sort_values(by='year')
plt.scatter(x = year_mpvsorted['year'], y = year_mpvsorted['total_count'], color = 'navy')
plt.title('Fatal Encounters with Law Enforcement Over Time')
plt.xlabel('Year')
plt.ylabel('Number');

# %% [markdown]
# #### This first graph shows that the amount of fatal police encounters has increased over time. In 2013, the number of fatal police encounters was below 1,000 and in 2022, the number of fatal police encounters has increased to over 1,200. This differenece has a percent change of 20% over the 10 year time period. The rate of increase has not stayed the same, but this graph indicates police violence is worsening overtime.

# %%
newstatecount = state_mpv.set_index('state')
newstatecount = newstatecount.drop('DC')

m = folium.Map(location=[36, -98], zoom_start=4) 

state_geo = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json" 

folium.Choropleth(
  geo_data=state_geo,
  data = newstatecount['state_count'],
  key_on="feature.id",
  fill_color="Purples"
).add_to(m)

# %% [markdown]
# ### Amount of Police Violence by State in 2022

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### This map displays the count of fatal police encounters for the entire 10 year time period by states. On this map, California stands out as a state with high amounts of fatal police encounters with the rest of the country at relativly low values. This map does not account for population. Because California is a highly populated state, there may be a higher number of violence, but per capita the value may be lower.

# %%
mpv_sorted.plot(kind = 'barh',
                          x = 'state',
                          y = 'percap',
                          figsize = (8,9),
                          color = "lightsteelblue", ec="navy",
                          title = 'Fatal Encounters with Police',
                         xlabel = 'per 1,000,000 people',
                         ylabel = 'State');

# %% [markdown]
# #### This chart displays the number of fatal police encounters per 1 million people by state in 2022. These values were found by dividing the amount of police violence in 2022 by the population of the state. The bar chart indicates that Missouri, Arkansas, and Iowa have the highest per capita rate of fatal police encounters. A majority of the states in the US have relativly low per capita rates of violence.

# %%
mpv_percap = mpv_merged.set_index('state')
mpv_percap = mpv_percap.drop('DC')

q = folium.Map(location=[36, -98], zoom_start=4) 

bins = list(mpv_merged["percap"].quantile([0, 0.25, 0.5, 0.75, 1]))

state_geo = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json" 

folium.Choropleth(
  geo_data=state_geo,
  data = mpv_percap['percap'],
  key_on="feature.id",
  fill_color="Blues", bins=bins
).add_to(q)

# %% [markdown]
# #### Another way to display the per capita rates from the graph above is to display the data geographically. The darker colors on this map show states with higher per capita amounts of police violence. Since the distribution of per capita values is so varied, the colors on this map are shown by quartile. Similar to the graph above, Missouri, Arkansas, and Iowa stand out as states with high per capita violence. Unlike the first map, California does not stand out as a place with high violence. The New England Region on this map stands out as a region with very low per capita fatal police encounters, indicated by the lightest blue color.

# %% [markdown]
# ### Police Violence by State Per 1,000,000 People

# %%
q
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Prisons and COVID-19

# %%
geometry = gpd.points_from_xy(lfc.Longitude, lfc.Latitude)
lfc_geodf = gpd.GeoDataFrame(lfc, geometry = geometry)

gdf = gpd.GeoDataFrame(
    lfc, geometry=gpd.points_from_xy(lfc.Longitude, lfc.Latitude))

gdf=gdf.dropna(subset=['Longitude'])

gdf=gdf.dropna(subset=['Latitude'])

gdf_state = gdf.loc[gdf['Jurisdiction'] == 'state']
gdf_fed = gdf.loc[gdf['Jurisdiction'] == 'federal']
gdf_county = gdf.loc[gdf['Jurisdiction'] == 'county']
gdf_imm = gdf.loc[gdf['Jurisdiction'] == 'immigration']

p = folium.Map(location=[36, -98], zoom_start=4)

for i, j in gdf_state.iterrows():
    location = [j['Latitude'], j['Longitude']]
    folium.CircleMarker(location, radius = 1, color = 'red').add_to(p)
    
for i, j in gdf_fed.iterrows():
    location = [j['Latitude'], j['Longitude']]
    folium.CircleMarker(location, radius = 1, color = 'purple').add_to(p)
    
for i, j in gdf_county.iterrows():
    location = [j['Latitude'], j['Longitude']]
    folium.CircleMarker(location, radius = 1, color = 'blue').add_to(p)
    
for i, j in gdf_imm.iterrows():
    location = [j['Latitude'], j['Longitude']]
    folium.CircleMarker(location, radius = 1, color = 'green').add_to(p)

# %% [markdown]
# ### Facility Locations in the United States

# %%
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### This map shows the location of prison facilities in the United States. Each color represents a different type of jursdiction. Red represents state facilities, blue represents county facilities, purple represents federal facilities, and green represents immigration facilities. According to this map, there appears to be a high number of state facilites, but this number is skewed because the original dataset does not track all facilites in the United States. For example, the UCLA Behind Bars dataset only collects information on select county jail facilities, which explains the underrepresentation of county jails across the country.

# %%
CA_covid = lfc.loc[ lfc['State'] == 'California' ]
CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Residents.Deaths'].sum()

data_dict = {'State': CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Residents.Deaths'].sum(), 
             'County': CA_covid.loc[CA_covid['Jurisdiction'] == 'county', 'Residents.Deaths'].sum(),
             'Federal': CA_covid.loc[CA_covid['Jurisdiction'] == 'federal', 'Residents.Deaths'].sum()}


in_type = list(data_dict.keys())
sums = list(data_dict.values())

plt.bar(range(len(data_dict)), sums, tick_label=in_type,
        color = "lightsteelblue", ec="navy")
plt.title("COVID Deaths in California Prisons")
plt.xlabel("Institution Type")
plt.ylabel("Number of Deaths");
plt.show()

# %% [markdown]
# #### This graph was created using data from UCLA Law's Behind Bars project. I first created a subset of data to only show California values, then created a dictionary of sums of the Covid deaths by institution type. This graph could be misleading as the values are not per capita, so though state prisons have the highest amount of Covid deaths, it also may be the most populated. I chose to focus on California because the Behind Bars dataset collects state, federal, and county data for the state of California.

# %%
data_percap = {'State': CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Residents.Deaths'].sum()/CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Residents.Population'].sum(), 
             'County': CA_covid.loc[CA_covid['Jurisdiction'] == 'county', 'Residents.Deaths'].sum()/CA_covid.loc[CA_covid['Jurisdiction'] == 'county', 'Residents.Population'].sum(),
            'Federal': CA_covid.loc[CA_covid['Jurisdiction'] == 'federal', 'Residents.Deaths'].sum()/CA_covid.loc[CA_covid['Jurisdiction'] == 'federal', 'Residents.Population'].sum()}


in_type = list(data_percap.keys())
sums = list(data_percap.values())

plt.bar(range(len(data_percap)), sums, tick_label=in_type,
        color = "lightsteelblue", ec="navy")
plt.title("COVID Deaths in California Prisons Per Capita")
plt.xlabel("Institution Type")
plt.ylabel("Per Capita Deaths");
plt.show()

# %% [markdown]
# #### This graph tells a very different story. When Covid deaths are calculated per capita, county jails are much more deadly with a per capita death rate of 0.006. By this measure, fedearl prisons are the least deadly with the lowest per capita rate of covid deaths. The UCLA Behind Bars dataset is in a moment of transition where they are about to start collecting all death information. Once that data is released, I would be interested in graphing this chart again and see if these trends remain consistent for all deaths in prisons.

# %%
groups = ['Federal', 'State', 'County']
resident = [CA_covid.loc[CA_covid['Jurisdiction'] == 'federal', 'Residents.Confirmed'].sum(),
           CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Residents.Confirmed'].sum(),
           CA_covid.loc[CA_covid['Jurisdiction'] == 'county', 'Residents.Confirmed'].sum()]
staff = [CA_covid.loc[CA_covid['Jurisdiction'] == 'federal', 'Staff.Confirmed'].sum(),
        CA_covid.loc[CA_covid['Jurisdiction'] == 'state', 'Staff.Confirmed'].sum(),
        CA_covid.loc[CA_covid['Jurisdiction'] == 'county', 'Staff.Confirmed'].sum()]


X_axis = np.arange(len(groups))
  
plt.bar(X_axis - 0.2, resident, 0.4, label = 'Resident', color = 'lightsteelblue', ec = 'navy')
plt.bar(X_axis + 0.2, staff, 0.4, label = 'Staff', color = 'bisque', ec = 'darkorange')
  
plt.xticks(X_axis, groups)
plt.xlabel("Jurisdiction")
plt.ylabel("Number of Covid Cases")
plt.title("Covid Cases for Residents and Staff in Prisons")
plt.legend()
plt.show()

# %%
ratio = [i / j for i, j in zip(staff, resident)]
ratio
# Out:
# [0.0, 0.6219686948853616, 0.4342123117282555]

# %% [markdown]
# #### The above chart shows the number of Covid cases in Federal, State, and County prisons and jails, divided between residents and staff. This graph is not per capita because the initial dataset does not have a total count of staff at each facility. There are more Covid cases for residents because they have a higher population than staff. From this, I also calculated ratios for each jursidiction type.
#
# #### There were no cases of Covid for Federal prison staff, so there is not a ratio. The ratio for state prisons is 0.62. The ratio for county jails is 0.43. This tells me that proportionally, more residents are getting Covid compared to the staff. This aligns with the findings of the per capita graph above that county jails are more transmissible and dangerous than state prisons.

# %% [markdown]
# # Discussion
# ---

# %% [markdown]
# This data exploration indicates several important trends of police violence and prison conditions that are worth further investigation.
#
# 1. States are not equal in the distribution of police violence. States that have higher police violence should be examined for structural and cultural reasons that could explain the rates of violence. Similarly, states with lower police violence should also be studied to explain their low rates that could provide a model for replicating low police violence.
#
#
# 2. County facilities appear to be more dangerous than other facility types, at least in terms of COVID-19 deaths. As more data is released surrounding other causes of deaths within prisons, a similar analysis should be done to prevent deaths. These trends illuminate where attention should be focused to lower danger.
#
#
# 3. Data surrounding police violence and prison safety are incomplete. Especially on the prison safety side, there is not enough data collected and published to fully explore the trends. For example, I wanted to compare COVID-19 deaths between residents and staff per capita, but the total number staff at each facility was not recorded.

# %% [markdown]
# |Data Used|
# |:---:|
# |[Mapping Police Violence](https://mappingpoliceviolence.org/)|
# |[UCLA Law Behind Bars](https://uclacovidbehindbars.org/)|
# |[Folium US Boundaries](https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json)
# |[US Census](https://data.census.gov/)|
